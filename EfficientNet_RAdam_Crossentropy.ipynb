# %%
import json
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_addons as tfa
import matplotlib.pyplot as plt

from packages.DataProcessing import tfrecords
from packages.DataAugmentation import dataAugmentation
from packages.Model_EfficientNet import get_model

plt.style.use('_mpl-gallery')
# Out:
# WARNING:tensorflow:Mixed precision compatibility check (mixed_float16): WARNING
# Your GPU may run slowly with dtype policy mixed_float16 because it does not have compute capability of at least 7.0. Your GPU:
#   NVIDIA GeForce GTX 1050, compute capability 6.1
# See https://developer.nvidia.com/cuda-gpus for a list of GPUs and their compute capabilities.
# If you will use compatible GPU(s) not attached to this host, e.g. by running a multi-worker model, you can ignore this warning. This message will only be logged once

# %%
config = json.load(open("./conf/config.json"))

# %%
N_SPLITS = config["DataProcess"]["N_SPLITS"]
IMG_HEIGHT = config["DataProcess"]["IMG_HEIGHT"]
IMG_WIDTH = config["DataProcess"]["IMG_WIDTH"]
BATCH_SIZE = config["TrainCycle"]["BATCH_SIZE"]
EPOCHS = config["TrainCycle"]["EPOCHS"]
PATIENCE = config["TrainCycle"]["PATIENCE"]
MAX_LR = config["TrainCycle"]["MAX_LR"]
MIN_LR = config["TrainCycle"]["MIN_LR"]

# %%
class_names = np.load("./output/class_names.npy", allow_pickle=True)
num_classes = len(class_names)

# %%
train_target = np.load("./output/train_target.npy", allow_pickle=True)
valid_target = np.load("./output/valid_target.npy", allow_pickle=True)

# %%
# Reading TFRecords
records = tfrecords(IMG_HEIGHT, IMG_WIDTH)
train_ds = records.get_dataset(f'./output/tfrecords/train.tfrecords')
valid_ds = records.get_dataset(f'./output/tfrecords/valid.tfrecords')

# %%
# Data augmentation
aug = dataAugmentation()
train_ds = train_ds.map(aug.augment_iamge, num_parallel_calls=tf.data.AUTOTUNE)

# %%
train_ds = train_ds.batch(BATCH_SIZE).prefetch(buffer_size=tf.data.AUTOTUNE).repeat()
valid_ds = valid_ds.batch(BATCH_SIZE).prefetch(buffer_size=tf.data.AUTOTUNE).repeat()

# %%
image_batch, label_batch = next(iter(train_ds))

plt.figure(figsize=(9, 6))
for i in range(6):
    ax = plt.subplot(2, 3, i + 1)
    plt.imshow(image_batch[i].numpy().astype(np.uint8))
    label = label_batch[i].numpy()
    plt.title(class_names[label])
    plt.axis("off")

# %%
# Build Model

model = get_model(input_shape=(IMG_HEIGHT, IMG_WIDTH, 3), output_shape=num_classes)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  efficientnetv2-b0 (Function  (None, 8, 8, 1280)       5919312
#  al)
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense (Dense)               (None, 100)               128100
#
# =================================================================
# Total params: 6,047,412
# Trainable params: 5,986,804
# Non-trainable params: 60,608
# _________________________________________________________________

# %%
train_classes, train_counts = np.unique(train_target, return_counts=True)

weight = (1/train_counts) * (len(train_target)/num_classes)
class_weight = {i:weight[i] for i in range(len(weight))}

# %%
steps_per_epoch = len(train_target)//BATCH_SIZE
validation_steps = len(valid_target)//BATCH_SIZE

# %%
model.compile(optimizer=tfa.optimizers.RectifiedAdam(learning_rate=MAX_LR,
                                                     total_steps=EPOCHS*steps_per_epoch,
                                                     warmup_proportion=0.2,
                                                     min_lr=MIN_LR), 
              loss=tf.losses.SparseCategoricalCrossentropy(), 
              metrics=['accuracy'])

# %%
my_callbacks = tf.keras.callbacks.EarlyStopping(patience=PATIENCE, 
                                                monitor='val_loss', 
                                                restore_best_weights=True)

# %%
history = model.fit(train_ds, 
                    validation_data=valid_ds,
                    epochs=EPOCHS,
                    callbacks=[my_callbacks],
                    class_weight=class_weight,
                    steps_per_epoch=steps_per_epoch,
                    validation_steps=validation_steps)
# Out:
# Epoch 1/80
# 2080/2080 [==============================] - 841s 387ms/step - loss: 4.6557 - accuracy: 0.0128 - val_loss: 4.5436 - val_accuracy: 0.0236
# Epoch 2/80
# 2080/2080 [==============================] - 820s 392ms/step - loss: 4.2262 - accuracy: 0.0549 - val_loss: 3.3559 - val_accuracy: 0.1726
# Epoch 3/80
# 2080/2080 [==============================] - 817s 393ms/step - loss: 3.4572 - accuracy: 0.1615 - val_loss: 2.4310 - val_accuracy: 0.3503
# Epoch 4/80
# 2080/2080 [==============================] - 792s 381ms/step - loss: 2.9258 - accuracy: 0.2527 - val_loss: 2.0029 - val_accuracy: 0.4452
# Epoch 5/80
# 2080/2080 [==============================] - 796s 383ms/step - loss: 2.5863 - accuracy: 0.3199 - val_loss: 1.7998 - val_accuracy: 0.4894
# Epoch 6/80
# 2080/2080 [==============================] - 792s 381ms/step - loss: 2.3636 - accuracy: 0.3713 - val_loss: 1.5330 - val_accuracy: 0.5709
# Epoch 7/80
# 2080/2080 [==============================] - 793s 381ms/step - loss: 2.2204 - accuracy: 0.4088 - val_loss: 1.5051 - val_accuracy: 0.5736
# Epoch 8/80
# 2080/2080 [==============================] - 789s 379ms/step - loss: 2.1311 - accuracy: 0.4211 - val_loss: 1.3711 - val_accuracy: 0.6129
# Epoch 9/80
# 2080/2080 [==============================] - 784s 377ms/step - loss: 2.0596 - accuracy: 0.4449 - val_loss: 1.4813 - val_accuracy: 0.6014
# Epoch 10/80
# 2080/2080 [==============================] - 800s 384ms/step - loss: 1.9889 - accuracy: 0.4577 - val_loss: 1.6798 - val_accuracy: 0.5635
# Epoch 11/80
# 2080/2080 [==============================] - 800s 385ms/step - loss: 1.9453 - accuracy: 0.4639 - val_loss: 1.3070 - val_accuracy: 0.6355
# Epoch 12/80
# 2080/2080 [==============================] - 811s 390ms/step - loss: 1.9068 - accuracy: 0.4730 - val_loss: 1.3712 - val_accuracy: 0.6371
# Epoch 13/80
# 2080/2080 [==============================] - 790s 380ms/step - loss: 1.8873 - accuracy: 0.4818 - val_loss: 1.1863 - val_accuracy: 0.6640
# Epoch 14/80
# 2080/2080 [==============================] - 787s 378ms/step - loss: 1.8405 - accuracy: 0.4937 - val_loss: 1.4160 - val_accuracy: 0.6178
# Epoch 15/80
# 2080/2080 [==============================] - 790s 380ms/step - loss: 1.8235 - accuracy: 0.4970 - val_loss: 1.3902 - val_accuracy: 0.6214
# Epoch 16/80
# 2080/2080 [==============================] - 794s 382ms/step - loss: 1.7900 - accuracy: 0.5067 - val_loss: 1.6297 - val_accuracy: 0.5696
# Epoch 17/80
# 2080/2080 [==============================] - 789s 379ms/step - loss: 1.7748 - accuracy: 0.5143 - val_loss: 1.2374 - val_accuracy: 0.6760
# Epoch 18/80
# 2080/2080 [==============================] - 790s 380ms/step - loss: 1.6540 - accuracy: 0.5435 - val_loss: 1.0848 - val_accuracy: 0.7017
# Epoch 19/80
# 2080/2080 [==============================] - 792s 381ms/step - loss: 1.5850 - accuracy: 0.5560 - val_loss: 0.8830 - val_accuracy: 0.7477
# Epoch 20/80
# 2080/2080 [==============================] - 784s 377ms/step - loss: 1.5009 - accuracy: 0.5802 - val_loss: 1.2785 - val_accuracy: 0.6872
# Epoch 21/80
# 2080/2080 [==============================] - 798s 384ms/step - loss: 1.4216 - accuracy: 0.5951 - val_loss: 0.9323 - val_accuracy: 0.7376
# Epoch 22/80
# 2080/2080 [==============================] - 763s 367ms/step - loss: 1.3721 - accuracy: 0.6169 - val_loss: 0.9042 - val_accuracy: 0.7509
# Epoch 23/80
# 2080/2080 [==============================] - 756s 363ms/step - loss: 1.3088 - accuracy: 0.6285 - val_loss: 0.7940 - val_accuracy: 0.7810
# Epoch 24/80
# 2080/2080 [==============================] - 761s 366ms/step - loss: 1.2660 - accuracy: 0.6432 - val_loss: 0.7762 - val_accuracy: 0.7799
# Epoch 25/80
# 2080/2080 [==============================] - 773s 372ms/step - loss: 1.1998 - accuracy: 0.6564 - val_loss: 0.8053 - val_accuracy: 0.7716
# Epoch 26/80
# 2080/2080 [==============================] - 756s 364ms/step - loss: 1.1653 - accuracy: 0.6640 - val_loss: 0.7066 - val_accuracy: 0.7947
# Epoch 27/80
# 2080/2080 [==============================] - 779s 375ms/step - loss: 1.1020 - accuracy: 0.6781 - val_loss: 0.9063 - val_accuracy: 0.7567
# Epoch 28/80
# 2080/2080 [==============================] - 749s 360ms/step - loss: 1.0743 - accuracy: 0.6875 - val_loss: 0.8218 - val_accuracy: 0.7785
# Epoch 29/80
# 2080/2080 [==============================] - 758s 364ms/step - loss: 1.0233 - accuracy: 0.7061 - val_loss: 0.7955 - val_accuracy: 0.7937
# Epoch 30/80
# 2080/2080 [==============================] - 768s 369ms/step - loss: 0.9893 - accuracy: 0.7120 - val_loss: 0.7062 - val_accuracy: 0.8070
# Epoch 31/80
# 2080/2080 [==============================] - 750s 361ms/step - loss: 0.9561 - accuracy: 0.7206 - val_loss: 0.5975 - val_accuracy: 0.8306
# Epoch 32/80
# 2080/2080 [==============================] - 745s 358ms/step - loss: 0.9434 - accuracy: 0.7272 - val_loss: 0.6717 - val_accuracy: 0.8173
# Epoch 33/80
# 2080/2080 [==============================] - 763s 367ms/step - loss: 0.9082 - accuracy: 0.7349 - val_loss: 0.6022 - val_accuracy: 0.8321
# Epoch 34/80
# 2080/2080 [==============================] - 772s 371ms/step - loss: 0.8541 - accuracy: 0.7488 - val_loss: 0.7183 - val_accuracy: 0.8144
# Epoch 35/80
# 2080/2080 [==============================] - 760s 366ms/step - loss: 0.8224 - accuracy: 0.7587 - val_loss: 0.6847 - val_accuracy: 0.8285
# Epoch 36/80
# 2080/2080 [==============================] - 758s 365ms/step - loss: 0.8155 - accuracy: 0.7635 - val_loss: 0.7382 - val_accuracy: 0.8317

# %%
model.save(f'./output/model_E_R_C.h5')

# %%
# Validate the Model

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
ax1.set_title('Accuracy')
ax1.plot(history.history['accuracy'], 'r', marker="o", label='accuracy')
ax1.plot(history.history['val_accuracy'], 'g', marker="x", label='val_accuracy')
ax1.legend()

ax2.set_title('Loss')
ax2.plot(history.history['loss'], 'r', marker="o", label='loss')
ax2.plot(history.history['val_loss'], 'g', marker="x", label='val_loss')
ax2.legend()

plt.show()

# %%
val_preds = model.predict(valid_ds, steps=validation_steps)
val_preds = np.argmax(val_preds, axis=1)

# %%
matrix = tf.math.confusion_matrix(valid_target[:validation_steps * BATCH_SIZE], val_preds).numpy()

plt.figure(figsize=(6, 6))
plt.imshow(matrix)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Class")
plt.ylabel("True Class")
plt.grid(False)
plt.show()

# %% [markdown]
# ## Submit the Result

# %%
def process_data_test(path):
    img = tf.io.read_file(path)
    img = tf.io.decode_png(img, channels=3)
    img = tf.image.resize(img, size=[IMG_HEIGHT, IMG_WIDTH])
    return img

# %%
df = pd.read_csv('./input/sample_submission.csv')

# %%
path = './input/test/'
test_images = np.array([path+i for i in df['filename']])

test_ds = tf.data.Dataset.from_tensor_slices(test_images)
test_ds = test_ds.map(process_data_test, num_parallel_calls=tf.data.AUTOTUNE)

# %%
test_ds = test_ds.batch(BATCH_SIZE)
preds = model.predict(test_ds)
preds = np.argmax(preds, axis=1)
preds = [class_names[i] for i in preds]

# %%
df['cultivar'] = preds
df.to_csv(f'./output/E_R_C.csv', index=False)
